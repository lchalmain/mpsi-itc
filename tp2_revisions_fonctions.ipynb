# %% [markdown]
# # <center><a href='https://notebook.basthon.fr/?from=https://raw.githubusercontent.com/lchalmain/mpsi-itc/main/tp2_revisions_fonctions.ipynb'>TP 2 : Révisions - fonctions <img src=https://framagit.org/uploads/-/system/project/avatar/55763/basthon_shadow.png width=100></a></center>

# %% [markdown]
# **<u>Rappel :</u>**
# * La combinaison **CTRL + ENTREE** permet d'exécuter une cellule.
# * La combinaison **MAJ + ENTREE** permet d'exécuter une cellule *et passer à la suivante*.

# %% [markdown]
# ### <span style = "color:purple">Pour chaque exercice, il est nécessaire de tester ses fonctions à l'aide d'un jeu de tests pertinent.</span>

# %% [markdown]
# ### <span style = "color:orange">À la fin du TP, pensez à télécharger votre notebook modifié en cliquant sur l'icone correspondant !</span>

# %% [markdown]
# # Fonctions
#
# Une fonction se définie comme ceci :
# ```python
# def ma_fonction(mon_argument):
#     insructions
# ```
# On utilisera l'instruction ```return``` pour interrompre l'exécution et renvoyer un résultat.
#
# Par exemple, la fonction ci-dessous renvoie le carré d'un nombre :

# %%
def carre(x):
    return x ** 2

carre(16)

# %% [markdown]
# Pour une fonction à plusieurs arguments on écrit par exemple : `def ma_fonction(arg1, arg2, arg3):`.
#
# <span style="color:red">**/!\ Attention :**</span> l'indentation (retrait en début de ligne) est extrêmement importante en Python !

# %% [markdown]
# **<span style = "color:purple">Exercice :</span>**
#
# 1. Écrire une fonction `perimetre` qui détermine le perimetre d'un cercle en fonction de son rayon (on pourra accéder à la variable `pi` du module math après l'avoir importée : `from math import pi`).
# 1. Écrire une fonction `norme` telle que `norme(x, y)` calcule la norme du vecteur $\vec{u}\begin{pmatrix}x\\ y\end{pmatrix}$.
# 1. Écrire une fonction `discrimant` telle que `discriminant(a, b, c)` calcule le discriminant du trinôme $ax^2 +bx + c$.
# 1. Est-il pertinent d'écrire une fonction réutilisant la fonction `discriminant` afin de déterminer le nombre de racines d'un trinôme ?
# <hr>

# %% [markdown]
# **<span style = "color:red">Commentaire :</span>** Pour s'assurer que le code exécuté produit bien le résultat escompté, il est nécessaire de fournir un jeu de tests.

# %%
#1

# %%
#2

# %%
#3

# %% [markdown]
# 4.

# %% [markdown]
# # Structure conditionnelle if-elif-else

# %% [markdown]
# Lorsqu'on souhaite exécuter des instruction différentes selon une condition à vérifier au préalable, on utilise la structure suivante :
# ```python
# if condition:
#     instructions        # si la condition est vérifiée, ce sont ces instructions qui sont exécutées
# else:
#     autres_instructions        # sinon, ce sont celles-ci
# ```
# <span style="color:red">**/!\ Attention :**</span>
# * Les `:` après la condition et le `else` sont obligatoires pour indiquer que des instructions vont suivre
# * toutes les instructions doivent être indentées de la même façon
#
# **Remarque :** S'il n'y a pas d'instruction particulière à exécuter dans le cas où la condition ne serait pas vérifiée, le `else` est inutile.

# %% [markdown]
# S'il y a plusieurs conditions différentes à vérifier, on utilise `elif` :
# ```python
# if condition_1:
#     instructions_1        # si la condition_1 est vérifiée, ce sont ces instructions qui sont exécutées
# elif condition_2:
#     instructions_2        # si la condition_2 est vérifiée, ce sont ces instructions qui sont exécutées
# elif condition_3:
#     instructions_3        # si la condition_3 est vérifiée, ce sont ces instructions qui sont exécutées
# else:
#     autres_instructions        # sinon, ce sont celles-ci
# ```

# %% [markdown]
# **<span style = "color:purple">Exercice :</span>**
#
# 1. Écrire une fonction `est_pair` qui teste si un entier est pair ou non. Le résultat renvoyé sera `True`ou `False`. On rappelle que `a//b` et `a%b` correspondent respectivement au quotient et au reste de la division euclidienne de `a` par `b`.
# 1. Écrire une fonction `syrac` telle que `syrac(n)` renvoie le terme suivant `n` de la suite de Syracuse :
# $\begin{cases} \displaystyle\frac{n}2 & \text{si $n$ est pair} \\ 3n+1 & \text{sinon} \end{cases}$
# 1. Écrire une fonction `nb_jours` telle que `nb_jours(mois)` renvoie le nombre de jours du mois de l'année 2022, les mois étants saisis par leur numéro. Ex : `nb_jours(2)` renvoie 28 car il y avait 28 jours au mois de février.
# 1. Écrire une fonction `est_voyelle` telle que `est_voyelle(lettre)` renvoie `True` si `lettre` est une voyelle et `False` sinon.
# <hr>

# %%
#1

# %%
#2

# %%
#3

# %%
#4

# %% [markdown]
# # Boucle bornée (for)

# %% [markdown]
# Lorsqu'on souhaite répéter un certain nombre de fois une même séquence d'instructions, on utilise une boucle for, selon la syntaxe suivante :
# ```python
# for i in range(n):        # i parcours les indices de 0 à n-1
#     instructions
# ```
# ou bien :
# ```python
# for i in range(n, m):        # i parcours les indices de n à m-1
#     instructions
# ```
# **Remarque :** en fait, on peut itérer autrement qu'avec `range` mais ce n'est pas au programme (hors dictionnaires).

# %% [markdown]
# **<span style = "color:purple">Exercice :</span>**
#
# 1. Écrire une fonction `compte_voy` telle que `compte_voy(mot)` renvoie le nombre de voyelles dans le mot `mot`. On pourra réutiliser la fonction `est_voyelle` définie plus haut.
# 1. Écrire une fonction `max` qui renvoie l'élément maximum d'une liste d'entiers non vide.
# 1. Écrire une fonction `syracuse` telle que `syracuse(a, n)` renvoie la **liste** des `n` termes suivant le terme `a` dans la suite de Syracuse vue précédemment. Ex : `syracuse(3, 5)` renvoie la liste `[10, 5, 16, 8, 4]`.
# 1. Écrire une fonction `parite` telle que `parite(liste)` renvoie la proportion de nombres pairs dans la liste d'entiers `liste`.
# <hr>

# %%
#1

# %%
#2

# %%
#3

# %%
#4

# %% [markdown]
# # Boucle non bornée (while)

# %% [markdown]
# Lorsque l'on souhaite répéter une séquence d'instructions tant qu'une certaine condition est vérifiée on utilise la syntaxe suivante :
# ```python
# while condition:
#     instructions
# ```

# %% [markdown]
# **<span style = "color:purple">Exercice :</span>**
#
# 1. Écrire une fonction `tps_vol` telle que `tps_vols(a)` renvoie le temps de vol de la suite de Syracuse en partant de `a`, c'est-à-dire le nombre d'étapes nécessaires avant de tomber sur le nombre 1.<br>
# **Remarque :** selon la conjecture de Syracuse, on finit toujours par tomber sur 1, peu importe le nombre choisi au départ.
# 1. Importer la fonction randint du module random (`from random import randint`) puis définir une fonction `double_6` telle que `double_6()` simule le lancer de deux dés (non truqués) et renvoie le nombre de lancers qui auront été nécessaires pour faire un double 6.<br>
# **Remarque :** `randint(n, m)` génère un entier aléatoirement entre `n` et `m` inclus.
# 1. Écrire une fonction `lancers` telle que `lancers(n)` renvoie une liste de 13 éléments (la liste est indicée de 0 à 12) correspondant à la simulation suivante :
#     * On effectue des lancers de deux dés dont on note la somme obtenue
#     * À chaque fois, on met à jour la liste des effectifs de chaque entier (à cette étape, `liste[i]` donne le nombre de `i` obtenus)
#     * On s'arrête dès que l'un des nombres a été obtenu `n` fois
#
#     On renvoie la liste correspondant à la **fréquence** de chaque nombre obtenue lors des lancers.

# %%
#1

# %%
#2

# %%
#3
